# %% [markdown]
# # 贝叶斯统计推断

# %% [markdown]
# ### 对于高斯分布的对数似然

# %%
# %run fig_likelihood_gaussian.py

# %% [markdown]
# ### 后验高斯分布

# %%
# %run fig_posterior_gaussian.py

# %% [markdown]
# ### 高斯/高斯分布

# %%
# %run fig_distribution_gaussgauss.py
# Out:
# anderson-darling A^2 = 3088.1

# %% [markdown]
# ### 高斯误差分布

# %%
# %run fig_likelihood_gaussgauss.py

# %% [markdown]
# ### 二项式后验
#
# 实线是后验分布，虚线是高斯近似
#
# 后面是累积分布

# %%
# %run fig_posterior_binomial.py

# %% [markdown]
# ### 对于Cauchy分布的似然对数

# %%
# %run fig_likelihood_cauchy.py
# Out:
# mu from likelihood: [-0.36231884]
# gamma from likelihood: [ 0.81014493]
#
# mu from median -0.262569562313
# gamma from quartiles: 1.10950042396

# %% [markdown]
# ### Cauchy分布的后验

# %%
# %run fig_posterior_cauchy.py

# %% [markdown]
# ### 均匀分布的似然对数

# %%
# %run fig_likelihood_uniform.py
# Out:
# data extent: 0.0469547619255 9.88373838059

# %% [markdown]
# ### 直方图仓大小的选择
#
# Scott的规则，Freedman-Diaconis规则和Knuth股则是关于为直方图选择最优bin宽度的规则。 这些直方图基于从所示的pdf中抽取的5000个点。 左边是一个简单的正态分布。 在右边是在中心的拉普拉斯分布，在两翼上增加了两个小高斯峰。

# %%
# %run fig_hist_binsize.py
